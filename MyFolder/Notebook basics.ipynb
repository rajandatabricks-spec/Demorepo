# %%
a=20
b=30
c=a+b
print(c)

# %%
# %sql
select "this is my first sql"

# %% [markdown]
# # Title
# ## Title2
# ### Title3
#
# text with a **bold** and _Italic _in it.
# order list
# 1.first
# 2.second
# 3.third
#
# unordered list
# *coffe
# *tea
# *milk
#
# images :
# https://images.pexels.com/photos/674010/pexels-photo-674010.jpeg
#
# tables
# |user|usre_name|
# |----|---------|
# |1|Adam|
# |2|Rajan|
# |3|Vihaan|

# %%
# %run ./Includes/Setup

# %%
print(full_name)

# %%
# %fs ls 'databricks-datasets'

# %%
dbutils.help()

# %%
dbutils.fs.help()
